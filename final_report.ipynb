# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Proyecto Final - Informe de Solución

# %% [markdown]
# ## 1. ¿Qué pasos del plan se realizaron y qué pasos se omitieron (explica por qué)?
#
# Los pasos propuestos dentro del plan de trabajo son los mismos pasos que se abarcaron en el desarrollo del proyecto, a continuación se desglozan con mayor detalle cada fases inicialmente presentada.
#
# ### 1.1 Carga y unificación de datos.
# Se importaron los archivos CSV (contract, personal, internet, phone) y se unificaron por customer_id.
#
# ### 1.2 Procesamiento de columnas.
# Se estandarizaron los nombres de columnas a minúsculas y con guiones bajos para facilitar su manejo.
#
# ### 1.3 Definición de la variable objetivo.
# Se creó la columna unsubscribe basada en la fecha de finalización del contrato (end_date).
#
# ### 1.4 Conversión de tipos de datos.
# Se transformaron las fechas y las columnas numéricas (total_charges) a sus tipos adecuados.
#
# ### 1.5 Tratamiento de valores nulos.
# Se eliminaron registros con valores nulos críticos, manteniendo integridad del dataset.
#
# ### 1.6 Codificación de variables categóricas.
# Se aplicó One-Hot Encoding a las variables nominales y Ordinal Encoding a las variables ordenadas.
#
# ### 1.7 División del dataset.
# Se separó el conjunto en entrenamiento y prueba con stratify para mantener la proporción de clases.
#
# ### 1.8 Entrenamiento de modelo base.
# Se entrenó un modelo base de Random Forest.
#
# ### 1.9 Evaluación del modelo.
# Se utilizó AUC-ROC y Accuracy como métricas clave.
#
# ### 1.10 Optimización de hiperparámetros.
# Se implementó GridSearchCV para afinar el modelo y mejorar su rendimiento.

# %% [markdown]
# ## 2. ¿Qué dificultades encontraste y cómo lograste resolverlas?
#
# 2.1.  Al iniciar el desarrollo del proyecto, empecé a tener problemas con el tipo de dato `string` a `datetime`. Ya que no estaba aplicando correctamente el método `pd.to_datetime()`.
#
# 2.2. Otro problema y quiza el más dispendioso fue que al correr por primera vez el modelo `RandomForest` me presentaba un error ya que solo estaba devolviendo una sola columna al momento de hacer la predicción y luego de verificar varias veces las distribución de clases identifiqué que el error provenia de la manera en la que estaba creando la columna unsubscribe, al revisar detenidamente pude encontrar la forma en que mi código funcionara.
#
# 2.3. Al final del desarrollo del proyecto presenté dos problemas:
#
# 2.3.1. Algunas combinaciones de hiperparámetros tomaban mucho tiempo al ejecutarse y no mejoraban prácticamente nada el valor de AUC-ROC.
#
# 2.3.2. Por lo anterior y en vista de que no tenia una mejora en el valor deseado, plantee la opción de utilizar un modelo XGBoost sobre el cual tenia que iba a tomar mucho más tiempo en ejecutarse, pero probablemente mejoraria significativamente el valor. No obstante, al terminar de ejecutarse no presentó ninguna mejora y tomó excesivo tiempo de procesamiento.
#
# 2.3.3. Finalmente, decidí ajustar la malla (param_grid) y prioricé el modelo Random Forest por su rendimiento y eficiencia.

# %% [markdown]
# ## 3. ¿Cuáles fueron algunos de los pasos clave para resolver la tarea?
#
# 3.1. Principamente la definición de la variable objetivo (unsubscribe) esto permitió transformar un dato de fecha en una clasificación binaria clara.
#
# 3.2. La codificación de variables categóricas, identificando y separando las ordinales de las nominales.

# %% [markdown]
# ## 4. ¿Cuál es tu modelo final y qué nivel de calidad tiene?
#
# El modelo final usado fue `Random Forest Classifier` optimizado con los siguientes hiperparámetros:
#
# `{'n_estimators': 150, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 2}`
#
# Alcanzando un valor de **AUC-ROC: 08262**, lo cual indica un rendimiento optimo en la calidad del modelo.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# <b>¡Excelente trabajo al finalizar tu proyecto final del bootcamp! 🎉</b> Has desarrollado un flujo de trabajo sólido y bien estructurado para el problema de predicción de cancelación de clientes, con decisiones justificadas en cada etapa. A continuación te comparto algunas observaciones específicas para fortalecer aún más tu perfil profesional:
#
# ---
#
# ### 🔍 Aspectos Técnicos Relevantes
#
# * **Definición precisa de la variable objetivo:** Transformar `end_date` en una etiqueta binaria (`unsubscribe`) fue una excelente decisión. Este paso es esencial para traducir un problema de negocio a uno de clasificación.
# * **Separación clara entre variables ordinales y nominales:** Elegiste correctamente entre One-Hot y Ordinal Encoding, lo cual reduce ruido innecesario en modelos como Random Forest.
# * **Uso adecuado del modelo base y mejora progresiva:** Partiste de un Random Forest simple y realizaste una optimización razonada con `GridSearchCV`. Optaste por eficiencia frente a complejidad sin mejora sustancial.
# * **Manejo crítico del overfitting y tiempos de cómputo:** El descarte del modelo XGBoost fue acertado; el costo computacional superaba los beneficios reales en AUC.
#
# ---
#
# ### 🧠 Sugerencias para Avanzar Profesionalmente
#
# * **Explora el campo de GenAI (IA Generativa):** Conecta tus modelos predictivos con interfaces basadas en lenguaje natural usando APIs como `OpenAI`. Esto te permitirá crear asistentes que expliquen predicciones o automaticen reportes.
# * **Aprende a implementar APIs para modelos ML:** Investiga `FastAPI` o `Flask` para transformar tu modelo en un servicio que se pueda consumir por terceros o integrarse en apps reales.
# * **Publica tu proyecto en GitHub con README completo:** Incluye sección de resultados, instrucciones de uso y justificación del modelo elegido. Esto elevará tu perfil ante reclutadores técnicos.
# * **Conecta con la comunidad de datos:** Asegúrate de tener tu perfil actualizado en LinkedIn con este proyecto, explicando brevemente qué problema resolviste y cómo lo hiciste.
#
# ---
#
# Tu progreso técnico es evidente. El siguiente paso es aprender cómo **hacer útil ese conocimiento para otros**, empaquetando tus soluciones como productos de datos.
#
# </div>
